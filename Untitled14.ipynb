# %% [markdown]
# <a href="https://colab.research.google.com/github/yeamuhid/Meching-Learning-/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/CODE/carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
X = df[['Mileage' ]]
y = df['Sell Price($)']

# %%
X
# Out:
#     Mileage
# 0     69000
# 1     35000
# 2     57000
# 3     22500
# 4     46000
# 5     59000
# 6     52000
# 7     72000
# 8     91000
# 9     67000
# 10    83000
# 11    79000
# 12    59000
# 13    58780
# 14    82450
# 15    25400
# 16    28000
# 17    69000
# 18    87600
# 19    52000

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
X_train
# Out:
#     Mileage
# 11    79000
# 3     22500
# 9     67000
# 2     57000
# 12    59000
# 1     35000
# 17    69000
# 5     59000
# 4     46000
# 10    83000
# 16    28000
# 15    25400
# 13    58780
# 14    82450
# 0     69000
# 19    52000

# %%
X_train
# Out:
#     Mileage
# 11    79000
# 3     22500
# 9     67000
# 2     57000
# 12    59000
# 1     35000
# 17    69000
# 5     59000
# 4     46000
# 10    83000
# 16    28000
# 15    25400
# 13    58780
# 14    82450
# 0     69000
# 19    52000

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#     Mileage
# 6     52000
# 0     69000
# 14    82450
# 2     57000
# 15    25400
# 7     72000
# 11    79000
# 4     46000
# 19    52000
# 16    28000
# 18    87600
# 9     67000
# 5     59000
# 3     22500
# 1     35000
# 13    58780

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([18294.97677742, 36816.13105767, 37760.34676607, 38813.51044083,
#        13937.05812324, 25558.17453438])

# %%
clf.predict(Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-cdc2e4c76230> in <cell line: 1>()
# ----> 1 clf.predict(Y_test)
#
# NameError: name 'Y_test' is not defined

# %%
y_test
# Out:
# 11    19500
# 16    35500
# 15    35000
# 3     40000
# 8     12000
# 12    26000
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test,y_test)
# Out:
# 0.8746097620445648
