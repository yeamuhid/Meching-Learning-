# %% [markdown]
# <a href="https://colab.research.google.com/github/yeamuhid/Meching-Learning-/blob/main/Dummy_Variables_%26_One_Hot_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/CODE/carprices.csv')
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
dummies = pd.get_dummies(df['Car Model'])
dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0     False    True                  False
# 1     False    True                  False
# 2     False    True                  False
# 3     False    True                  False
# 4     False    True                  False
# 5      True   False                  False
# 6      True   False                  False
# 7      True   False                  False
# 8      True   False                  False
# 9     False   False                   True
# 10    False   False                   True
# 11    False   False                   True
# 12    False   False                   True

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6    False    True
# 1                  BMW X5    35000          34000         3    False    True
# 2                  BMW X5    57000          26100         5    False    True
# 3                  BMW X5    22500          40000         2    False    True
# 4                  BMW X5    46000          31500         4    False    True
# 5                 Audi A5    59000          29400         5     True   False
# 6                 Audi A5    52000          32000         5     True   False
# 7                 Audi A5    72000          19300         6     True   False
# 8                 Audi A5    91000          12000         8     True   False
# 9   Mercedez Benz C class    67000          22000         6    False   False
# 10  Mercedez Benz C class    83000          20000         7    False   False
# ...

# %%
merged = pd.concat([df,dummies],axis='columns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c940b2c913f6> in <cell line: 1>()
# ----> 1 merged = pd.concat([df,dummies],axis='columns')
#
# NameError: name 'dummies' is not defined

# %%
pd.get_dummies(df['Car Model'])
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0     False    True                  False
# 1     False    True                  False
# 2     False    True                  False
# 3     False    True                  False
# 4     False    True                  False
# 5      True   False                  False
# 6      True   False                  False
# 7      True   False                  False
# 8      True   False                  False
# 9     False   False                   True
# 10    False   False                   True
# 11    False   False                   True
# 12    False   False                   True

# %%
pd.get_dummies(df['Car Model'])
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0     False    True                  False
# 1     False    True                  False
# 2     False    True                  False
# 3     False    True                  False
# 4     False    True                  False
# 5      True   False                  False
# 6      True   False                  False
# 7      True   False                  False
# 8      True   False                  False
# 9     False   False                   True
# 10    False   False                   True
# 11    False   False                   True
# 12    False   False                   True

# %%
final = merged.drop(['Audi A5'], axis='columns')
final
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  BMW X5  \
# 0                  BMW X5    69000          18000         6    True
# 1                  BMW X5    35000          34000         3    True
# 2                  BMW X5    57000          26100         5    True
# 3                  BMW X5    22500          40000         2    True
# 4                  BMW X5    46000          31500         4    True
# 5                 Audi A5    59000          29400         5   False
# 6                 Audi A5    52000          32000         5   False
# 7                 Audi A5    72000          19300         6   False
# 8                 Audi A5    91000          12000         8   False
# 9   Mercedez Benz C class    67000          22000         6   False
# 10  Mercedez Benz C class    83000          20000         7   False
# 11  Mercedez Benz C class    79000          21000         7   False
# 12  Mercedez Benz C class    59000          33000         5   False
#
# ...

# %%
from sklearn.linear_model  import LinearRegression
model = LinearRegression()

# %%
X = final.drop('Sell Price($)', axis='columns')
X
# Out:
#                 Car Model  Mileage  Age(yrs)  BMW X5  Mercedez Benz C class
# 0                  BMW X5    69000         6    True                  False
# 1                  BMW X5    35000         3    True                  False
# 2                  BMW X5    57000         5    True                  False
# 3                  BMW X5    22500         2    True                  False
# 4                  BMW X5    46000         4    True                  False
# 5                 Audi A5    59000         5   False                  False
# 6                 Audi A5    52000         5   False                  False
# 7                 Audi A5    72000         6   False                  False
# 8                 Audi A5    91000         8   False                  False
# 9   Mercedez Benz C class    67000         6   False                   True
# 10  Mercedez Benz C class    83000         7   False                   True
# ...

# %%
y = final['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c1a2828403e> in <cell line: 1>()
# ----> 1 model.fit(X,y)
#
# NameError: name 'model' is not defined

# %%
model.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-585343871d29> in <cell line: 1>()
# ----> 1 model.score(X,y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     846         from .metrics import r2_score
#     847
# --> 848         y_pred = self.predict(X)
#     849         return r2_score(y, y_pred, sample_weight=sample_weight)
#     850
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     304             Returns predicted values.
#     305         """
# --> 306         return self._decision_function(X)
#     307
#     308     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     283         check_is_fitted(self)
#     284
# ...

# %%
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle= df
dfle['Car Model'] = le.fit_transform(dfle['Car Model'])
dfle
# Out:
#     Car Model  Mileage  Sell Price($)  Age(yrs)
# 0           1    69000          18000         6
# 1           1    35000          34000         3
# 2           1    57000          26100         5
# 3           1    22500          40000         2
# 4           1    46000          31500         4
# 5           0    59000          29400         5
# 6           0    52000          32000         5
# 7           0    72000          19300         6
# 8           0    91000          12000         8
# 9           2    67000          22000         6
# 10          2    83000          20000         7
# 11          2    79000          21000         7
# 12          2    59000          33000         5

# %%
dfle = df
dfle['Car Model'] = le.fit_transform(dfle['Car Model'])
dfle
# Out:
#     Car Model  Mileage  Sell Price($)  Age(yrs)
# 0           1    69000          18000         6
# 1           1    35000          34000         3
# 2           1    57000          26100         5
# 3           1    22500          40000         2
# 4           1    46000          31500         4
# 5           0    59000          29400         5
# 6           0    52000          32000         5
# 7           0    72000          19300         6
# 8           0    91000          12000         8
# 9           2    67000          22000         6
# 10          2    83000          20000         7
# 11          2    79000          21000         7
# 12          2    59000          33000         5

# %%
X = dfle[['Car Model','Mileage','Age(yrs)']].values
X
# Out:
# array([[    1, 69000,     6],
#        [    1, 35000,     3],
#        [    1, 57000,     5],
#        [    1, 22500,     2],
#        [    1, 46000,     4],
#        [    0, 59000,     5],
#        [    0, 52000,     5],
#        [    0, 72000,     6],
#        [    0, 91000,     8],
#        [    2, 67000,     6],
#        [    2, 83000,     7],
#        [    2, 79000,     7],
#        [    2, 59000,     5]])

# %%
y= dfle['Sell Price($)'].values
y
# Out:
# array([18000, 34000, 26100, 40000, 31500, 29400, 32000, 19300, 12000,
#        22000, 20000, 21000, 33000])

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
ohe.fit_transform(X)
# Out:
# <13x22 sparse matrix of type '<class 'numpy.float64'>'
# 	with 39 stored elements in Compressed Sparse Row format>
